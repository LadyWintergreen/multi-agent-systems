# %%
import torch
import copy
import numpy as np
import itertools
import random as rd

# %%
# !pip install torch

# %% [markdown]
# # Purpose
#
# Purpose of this branch is to test convergence properties of the network using one-hot-vectors for the state space instead of 0-3, as the OHV format may be easier for the network to operate on. Due to the need to operate on zero vectors we will
#
# - add a small noise function gamma to each OHV
# - use He initialisation for weight initialisation

# %%
class Environment():
    
    #fields:
    #a grid of size defined by parameter
    #b, a tuple repsenting the delivery location
    #a, a tuple representing the package location
    #size, an int representing the horizontal and vertical dimensions of the grid
    def __init__(self, size:int):
        self.size = size
        self.actions = ['north', 'south', 'west', 'east']
        self.reward_pickup = 50
        self.reward_deliver = 50
        self.reward_move = -1
        self.reset_env()
    
    def reset_env(self):
        combinations = list(itertools.product(list(range(self.size)), repeat=2))
        rd.shuffle(combinations)
        self.a, self.b, self.agent_coords = combinations[0:3]
        self.collected = 0
        self.done = False
        self.terminated = False
        self.test_length = 0 #an additional parameter to determine how long the environment has been active for
        self.setup_grid()

    def coordinates_to_noisy_ohv(self, coordinate:int):
        ohv = np.zeros(4)
        noise = np.random.normal(-1e-5, 1e-5, ohv.shape)
        ohv[coordinate] = 1
        ohv = ohv + noise
        return ohv

    #method to set up the original grid including a location
    def setup_grid(self):
        grid = np.zeros((self.size, self.size))
        self.grid = grid
        grid[self.a] = 1
        grid[self.b] = 2
        grid[self.agent_coords] = -1

    def get_state(self):
        #This method unpacks the coordinates into a tuple which can be used to index the qmatrix or for easy incorporation to the Deep Q Network
        # coords = [self.agent_coords[0], self.agent_coords[1], self.a[0], self.a[1], self.b[0], self.b[1]]
        # coords = [self.coordinates_to_noisy_ohv(c) for c in coords]
        # coords.append(np.array(self.collected))
        # return np.hstack(coords)
        # return np.ndarray.flatten(np.array(coords))

        return np.array([self.agent_coords[0], self.agent_coords[1], self.collected, self.a[0], self.a[1], self.b[0], self.b[1]])
    
    #Method which updates the location of the agent on the grid. Currently just zeroes whatever it landed on - can include other logic instead
    def move_agent(self, action):
        #For agent move, note that 0 = up, 1=down, 2=left, 3=right
        self.test_length += 1

        #Assign new coordinates for agent to exist at
        new_x, new_y = self.agent_coords
        if action == 'north' and self.agent_coords[1] > 0:
            new_y -= 1
        elif action == 'south' and self.agent_coords[1] < self.size - 1:
            new_y += 1
        elif action == 'west' and self.agent_coords[0] > 0:
            new_x -= 1
        elif action == 'east' and self.agent_coords[0] < self.size - 1:
             new_x += 1
        
        #Update the grid based on new agent coordinates
        self.grid[self.agent_coords] = 0
        self.agent_coords = (new_x, new_y)
        self.grid[self.agent_coords] = -1

        #Handle logic based on new agent location
        if self.collected == 0:
            if self.agent_coords == self.a:
                self.collected = 1
                reward = self.reward_pickup
            else:
                reward = self.reward_move
        
        else:
            if self.agent_coords == self.b:
                self.done = True
                reward = self.reward_deliver
            else:
                reward = self.reward_move

                #This code was considered test code which could be useful in exiting early
        if self.test_length > 70:
            self.terminated = True
        return reward, self.done, self.terminated

    def get_grid(self):
        return self.grid.tolist()

    # def plot_grid(self, snapshot, ax=None):
    #     if ax is None:
    #         fig, ax = plt.subplots()
    #         ax.set_facecolor('white')
    #     else:
    #         ax.clear()
        
    #     # Plot the grid
    #     ax.imshow(np.array([[0]]), cmap="bone", extent=[0, self.size, 0, self.size])

    #     for i in range(self.size):
    #         for j in range(self.size):
    #             cell_value = snapshot[i][j]
    #             if cell_value == -1:
    #                 # Display agent image in the cell
    #                 imagebox = OffsetImage(agent_img, zoom=0.08)
    #                 ab = AnnotationBbox(imagebox, (j + 0.5, self.size - i - 0.5), frameon=False)
    #                 ax.add_artist(ab)
    #             elif cell_value == 1:
    #                 # Display package image in the cell
    #                 imagebox = OffsetImage(package_img, zoom=0.03)
    #                 ab = AnnotationBbox(imagebox, (j + 0.5, self.size - i - 0.5), frameon=False)
    #                 ax.add_artist(ab)
    #             elif cell_value == 2:
    #                 # Display destination image in the cell
    #                 imagebox = OffsetImage(destinationB_img, zoom=0.05)
    #                 ab = AnnotationBbox(imagebox, (j + 0.5, self.size - i - 0.5), frameon=False)
    #                 ax.add_artist(ab)
    #             else:
    #                 ax.text(j + 0.5, self.size - i - 0.5, self.grid[i, j], ha='center', va='center', fontsize=20, color='black')
        
    #     # Set axis properties
    #     ax.set_xlim(0, self.size)
    #     ax.set_ylim(0, self.size)
    #     ax.set_xticks(np.arange(self.size) + 1)
    #     ax.set_yticks(np.arange(self.size) + 1)
    #     ax.set_xticklabels([])
    #     ax.set_yticklabels([])
    #     ax.grid(True, linewidth=2, color='white')
        
    #     # Set title
    #     ax.set_title("Package Delivery Agent")
        
    #     # Show the plot
    #     #plt.show()
    #     return ax

# %%
# Out:
# (2, 0)
# (3, 3)
# (1, 2)

# %%
# Define the TransportAgent agent
#new statespace size should be 25 - this represents six 4-size one-hot-vectors, plus a collected flag
class TransportAgent:
    def __init__(self, statespace_size=7, gamma=0.99, learning_rate=0.01, start_epsilon=1.0,
                 epsilon_decay_factor=0.997, min_epsilon=0.1, replay_buffer_size=1000,
                 batch_size=200, network_copy_frequency=500):
        self.statespace_size = statespace_size
        self.gamma = gamma
        self.learning_rate = learning_rate
        self.model2 = self.prepare_torch()
        self.memory = []  # Using a list instead of a deque
        self.epsilon = start_epsilon
        self.epsilon_min = min_epsilon
        self.epsilon_decay_factor = epsilon_decay_factor
        self.replay_buffer_size = replay_buffer_size
        self.batch_size = batch_size
        self.network_copy_frequency = network_copy_frequency
        self.steps_since_copy = 0  # Counter for network copy

    def prepare_torch(self):
        l1 = self.statespace_size
        l2 = 150
        l3 = 100
        l4 = 4
        self.model = torch.nn.Sequential(
            torch.nn.Linear(l1, l2),
            torch.nn.ReLU(),
            torch.nn.Linear(l2, l3),
            torch.nn.ReLU(),
            torch.nn.Linear(l3, l4)
        )

        model2 = copy.deepcopy(self.model)
        model2.load_state_dict(self.model.state_dict())
        self.loss_fn = torch.nn.HuberLoss()
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=self.learning_rate)
        return model2

    def update_target(self):
        if self.steps_since_copy >= self.network_copy_frequency:
            self.model2.load_state_dict(self.model.state_dict())
            self.steps_since_copy = 0
            print("Target model updated")

    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))
        if len(self.memory) > self.replay_buffer_size:
            self.memory.pop(0)  # Remove the oldest experience

    def get_qvals(self, state):
        state1 = torch.from_numpy(state).float()
        qvals_torch = self.model(state1)
        qvals = qvals_torch.data.numpy()
        return qvals

    def get_maxQ(self, s):
        return torch.max(self.model2(torch.from_numpy(s).float())).float()

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return np.random.choice(range(4))  # Random action
        q_values = self.get_qvals(state)
        return np.argmax(q_values[0])  # Greedy action

    def process_minibatch(self, minibatch):
        states = []
        actions = []
        targets = []
        for state, action, reward, next_state, done in minibatch:
            q_values = self.get_qvals(state)
            if done:
                q_values[action] = reward
            else:
                q_values[action] = reward + self.gamma * self.get_maxQ(next_state)
            states.append(state)
            actions.append(action)
            targets.append(q_values[0])
        return np.array(states), np.array(actions), np.array(targets) #this is returning a thruple of state transitions?

    def train_one_step(self, states, actions, targets):
        state1_batch = torch.from_numpy(states).float()
        # state1_batch = torch.Tensor([torch.from_numpy(s).float() for s in states])
        action_batch = torch.Tensor(actions)
        Q1 = self.model(state1_batch)
        X = Q1.gather(dim=1, index=action_batch.long().unsqueeze(dim=1)).squeeze()
        Y = torch.tensor(targets)
        loss = torch.nn.HuberLoss()(X, Y)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()
        return loss.item()

# %%
if __name__ == "__main__":
    # env = TransportEnv()  # Create the environment
    env = Environment(4)
    agent = TransportAgent(learning_rate=0.01, start_epsilon=1.0, epsilon_decay_factor=0.997,
                           min_epsilon=0.1, replay_buffer_size=5000, batch_size=100, network_copy_frequency=20)

    episodes = 1000
    for episode in range(episodes):
        env.reset_env()
        state = env.get_state()  # Reset the environment and get the initial state
        done = False
        terminated = False
        total_reward = 0
        episode_losses = []
        while (not done and not terminated):
            # print("state", state)
            action = agent.act(state)
            reward, done, terminated = env.move_agent(env.actions[action])
            next_state = env.get_state()
            # next_state, reward, done = env.step(env.actions[action])
            total_reward += reward
            agent.remember(state, action, reward, next_state, done)
            # print("agent.memory[-1]",agent.memory[-1])
            state = next_state

            # Training
            if len(agent.memory) > agent.batch_size:
                minibatch_indices = np.random.choice(len(agent.memory), agent.batch_size, replace=False)
                minibatch = [agent.memory[i] for i in minibatch_indices]
                states_batch, actions_batch, targets_batch = agent.process_minibatch(minibatch)
                loss = agent.train_one_step(states_batch, actions_batch, targets_batch)
                episode_losses.append(loss)
        agent.epsilon = max(agent.epsilon * agent.epsilon_decay_factor, agent.epsilon_min)
        if len(episode_losses) > 0:
            mean_loss = sum(episode_losses)/len(episode_losses)
        else:
            mean_loss = "n/a"
        agent.steps_since_copy += 1
        agent.update_target()
        # print("state", state)
        print(f"Episode: {episode + 1}, Total Reward: {total_reward}, Epsilon: {agent.epsilon} | Loss: {mean_loss}")
        print(f"Terminated: {terminated} | Done: {done}")
# Out:
# Episode: 1, Total Reward: 67, Epsilon: 0.99 | Loss: n/a
# Terminated: False | Done: True
# Episode: 2, Total Reward: 73, Epsilon: 0.9801 | Loss: n/a
# Terminated: False | Done: True
# Episode: 3, Total Reward: 88, Epsilon: 0.9702989999999999 | Loss: n/a
# Terminated: False | Done: True
# Episode: 4, Total Reward: 75, Epsilon: 0.96059601 | Loss: 28597.358241820337
# Terminated: False | Done: True
# Episode: 5, Total Reward: 57, Epsilon: 0.9509900498999999 | Loss: 12.161792821354336
# Terminated: False | Done: True
# Episode: 6, Total Reward: 98, Epsilon: 0.9414801494009999 | Loss: 3.7409040927886963
# Terminated: False | Done: True
# Episode: 7, Total Reward: 44, Epsilon: 0.9320653479069899 | Loss: 5.7337274397241655
# Terminated: False | Done: True
# Episode: 8, Total Reward: -20, Epsilon: 0.92274469442792 | Loss: 0.6463383050425582
# Terminated: True | Done: False
# Episode: 9, Total Reward: 67, Epsilon: 0.9135172474836407 | Loss: 0.46723340793645807
# Terminated: False | Done: True
# Target model updated
# Episode: 10, Total Reward: 35, Epsilon: 0.9043820750088043 | Loss: 0.4403500700544969
# Terminated: False | Done: True
# Episode: 11, Total Reward: 88, Epsilon: 0.8953382542587163 | Loss: 0.6272075995802879
# Terminated: False | Done: True
# Episode: 12, Total Reward: 56, Epsilon: 0.8863848717161291 | Loss: 0.5581921891729429
# Terminated: False | Done: True
# Episode: 13, Total Reward: -20, Epsilon: 0.8775210229989678 | Loss: 0.4276596068328371
# Terminated: True | Done: False
# Episode: 14, Total Reward: -20, Epsilon: 0.8687458127689781 | Loss: 0.45684631193703545
# Terminated: True | Done: False
# Episode: 15, Total Reward: 97, Epsilon: 0.8600583546412883 | Loss: 0.3147889157291502
# Terminated: False | Done: True
# Episode: 16, Total Reward: 76, Epsilon: 0.8514577710948754 | Loss: 0.6141281297940833
# Terminated: False | Done: True
# Episode: 17, Total Reward: -71, Epsilon: 0.8429431933839266 | Loss: 0.5553438907135015
# Terminated: True | Done: False
# Episode: 18, Total Reward: 71, Epsilon: 0.8345137614500874 | Loss: 0.4760188803437256
# Terminated: False | Done: True
# Episode: 19, Total Reward: -20, Epsilon: 0.8261686238355865 | Loss: 0.5278515062322775
# Terminated: True | Done: False
# Target model updated
# Episode: 20, Total Reward: 64, Epsilon: 0.8179069375972307 | Loss: 0.47253004200808246
# Terminated: False | Done: True
# Episode: 21, Total Reward: -71, Epsilon: 0.8097278682212583 | Loss: 0.6540242899012503
# Terminated: True | Done: False
# Episode: 22, Total Reward: -20, Epsilon: 0.8016305895390458 | Loss: 0.39278013183615207
# Terminated: True | Done: False
# Episode: 23, Total Reward: -71, Epsilon: 0.7936142836436553 | Loss: 0.3567555434562731
# Terminated: True | Done: False
# Episode: 24, Total Reward: -20, Epsilon: 0.7856781408072188 | Loss: 0.3937502846195162
# Terminated: True | Done: False
# Episode: 25, Total Reward: -20, Epsilon: 0.7778213593991465 | Loss: 0.3122613462621533
# Terminated: True | Done: False
# Episode: 26, Total Reward: 87, Epsilon: 0.7700431458051551 | Loss: 0.30658680144418515
# Terminated: False | Done: True
# Episode: 27, Total Reward: -20, Epsilon: 0.7623427143471035 | Loss: 0.39368552676997226
# Terminated: True | Done: False
# Episode: 28, Total Reward: -20, Epsilon: 0.7547192872036325 | Loss: 0.3638685978463323
# Terminated: True | Done: False
# Episode: 29, Total Reward: 42, Epsilon: 0.7471720943315961 | Loss: 0.413201040794714
# Terminated: False | Done: True
# Target model updated
# Episode: 30, Total Reward: 77, Epsilon: 0.7397003733882802 | Loss: 0.5519018535839859
# Terminated: False | Done: True
# Episode: 31, Total Reward: -71, Epsilon: 0.7323033696543974 | Loss: 0.402064807763861
# Terminated: True | Done: False
# Episode: 32, Total Reward: -20, Epsilon: 0.7249803359578534 | Loss: 0.30784066638961133
# Terminated: True | Done: False
# Episode: 33, Total Reward: -20, Epsilon: 0.7177305325982748 | Loss: 0.25497712546909407
# Terminated: True | Done: False
# Episode: 34, Total Reward: 72, Epsilon: 0.7105532272722921 | Loss: 0.27904385786193114
# Terminated: False | Done: True
# Episode: 35, Total Reward: 34, Epsilon: 0.7034476949995692 | Loss: 0.13245086439565057
# Terminated: False | Done: True
# Episode: 36, Total Reward: 48, Epsilon: 0.6964132180495735 | Loss: 0.1780031425141378
# Terminated: False | Done: True
# Episode: 37, Total Reward: -20, Epsilon: 0.6894490858690777 | Loss: 0.2749513260701271
# Terminated: True | Done: False
# Episode: 38, Total Reward: 39, Epsilon: 0.682554595010387 | Loss: 0.21707864116637038
# Terminated: False | Done: True
# Episode: 39, Total Reward: -71, Epsilon: 0.6757290490602831 | Loss: 0.223863741333562
# Terminated: True | Done: False
# Target model updated
# Episode: 40, Total Reward: -71, Epsilon: 0.6689717585696803 | Loss: 0.34076113166028477
# Terminated: True | Done: False
# Episode: 41, Total Reward: 65, Epsilon: 0.6622820409839835 | Loss: 0.3049974516285835
# Terminated: False | Done: True
# Episode: 42, Total Reward: 75, Epsilon: 0.6556592205741436 | Loss: 0.29424379104468107
# Terminated: False | Done: True
# Episode: 43, Total Reward: -71, Epsilon: 0.6491026283684022 | Loss: 0.40294704961133004
# Terminated: True | Done: False
# Episode: 44, Total Reward: -71, Epsilon: 0.6426116020847181 | Loss: 0.21230030861537877
# Terminated: True | Done: False
# Episode: 45, Total Reward: -20, Epsilon: 0.6361854860638709 | Loss: 0.21711140966578224
# Terminated: True | Done: False
# Episode: 46, Total Reward: 59, Epsilon: 0.6298236312032323 | Loss: 0.13175028280103254
# Terminated: False | Done: True
# Episode: 47, Total Reward: 42, Epsilon: 0.6235253948912 | Loss: 0.26648280893374854
# Terminated: False | Done: True
# Episode: 48, Total Reward: -71, Epsilon: 0.617290140942288 | Loss: 0.2914619251247055
# Terminated: True | Done: False
# Episode: 49, Total Reward: 81, Epsilon: 0.6111172395328651 | Loss: 0.4345104706707865
# Terminated: False | Done: True
# Target model updated
# Episode: 50, Total Reward: 96, Epsilon: 0.6050060671375365 | Loss: 0.3375029398788077
# Terminated: False | Done: True
# Episode: 51, Total Reward: -71, Epsilon: 0.5989560064661611 | Loss: 0.4380230136776448
# Terminated: True | Done: False
# Episode: 52, Total Reward: 60, Epsilon: 0.5929664464014994 | Loss: 0.4046605516473175
# Terminated: False | Done: True
# Episode: 53, Total Reward: 57, Epsilon: 0.5870367819374844 | Loss: 0.389457108072141
# Terminated: False | Done: True
# Episode: 54, Total Reward: 94, Epsilon: 0.5811664141181095 | Loss: 0.5818746448057937
# Terminated: False | Done: True
# Episode: 55, Total Reward: -71, Epsilon: 0.5753547499769285 | Loss: 0.48340301648967793
# Terminated: True | Done: False
# Episode: 56, Total Reward: 35, Epsilon: 0.5696012024771592 | Loss: 0.3505306849868641
# Terminated: False | Done: True
# Episode: 57, Total Reward: 92, Epsilon: 0.5639051904523876 | Loss: 0.50696473531425
# Terminated: False | Done: True
# Episode: 58, Total Reward: -71, Epsilon: 0.5582661385478638 | Loss: 0.4876965003954673
# Terminated: True | Done: False
# Episode: 59, Total Reward: -71, Epsilon: 0.5526834771623851 | Loss: 0.5004570840731208
# Terminated: True | Done: False
# Target model updated
# Episode: 60, Total Reward: -71, Epsilon: 0.5471566423907612 | Loss: 0.3803818224190712
# Terminated: True | Done: False
# Episode: 61, Total Reward: -20, Epsilon: 0.5416850759668536 | Loss: 0.5329134633066133
# Terminated: True | Done: False
# Episode: 62, Total Reward: -20, Epsilon: 0.536268225207185 | Loss: 0.4838644590193543
# Terminated: True | Done: False
# Episode: 63, Total Reward: 34, Epsilon: 0.5309055429551132 | Loss: 0.5074321403313019
# Terminated: False | Done: True
# Episode: 64, Total Reward: -71, Epsilon: 0.525596487525562 | Loss: 0.4525257181003198
# Terminated: True | Done: False
# Episode: 65, Total Reward: -71, Epsilon: 0.5203405226503064 | Loss: 0.41951941215133126
# Terminated: True | Done: False
# Episode: 66, Total Reward: -20, Epsilon: 0.5151371174238033 | Loss: 0.25150776988297185
# Terminated: True | Done: False
# Episode: 67, Total Reward: 90, Epsilon: 0.5099857462495653 | Loss: 0.2664813291697404
# Terminated: False | Done: True
# Episode: 68, Total Reward: -20, Epsilon: 0.5048858887870696 | Loss: 0.22566211728610117
# Terminated: True | Done: False
# Episode: 69, Total Reward: -71, Epsilon: 0.4998370298991989 | Loss: 0.22616990578791674
# Terminated: True | Done: False
# Target model updated
# Episode: 70, Total Reward: -71, Epsilon: 0.49483865960020695 | Loss: 0.21933386988192222
# Terminated: True | Done: False
# Episode: 71, Total Reward: -20, Epsilon: 0.4898902730042049 | Loss: 0.29957065748503353
# Terminated: True | Done: False
# Episode: 72, Total Reward: -20, Epsilon: 0.48499137027416284 | Loss: 0.11890078506547352
# Terminated: True | Done: False
# Episode: 73, Total Reward: -71, Epsilon: 0.4801414565714212 | Loss: 0.0785906045159055
# Terminated: True | Done: False
# Episode: 74, Total Reward: 51, Epsilon: 0.475340042005707 | Loss: 0.030067236986795642
# Terminated: False | Done: True
# Episode: 75, Total Reward: -71, Epsilon: 0.47058664158564995 | Loss: 0.07854402969238936
# Terminated: True | Done: False
# Episode: 76, Total Reward: -20, Epsilon: 0.4658807751697934 | Loss: 0.15696386951038246
# Terminated: True | Done: False
# Episode: 77, Total Reward: 73, Epsilon: 0.4612219674180955 | Loss: 0.12317076791102942
# Terminated: False | Done: True
# Episode: 78, Total Reward: -20, Epsilon: 0.45660974774391455 | Loss: 0.19333656476635336
# Terminated: True | Done: False
# Episode: 79, Total Reward: 51, Epsilon: 0.4520436502664754 | Loss: 0.11903873123025964
# Terminated: False | Done: True
# Target model updated
# Episode: 80, Total Reward: 80, Epsilon: 0.44752321376381066 | Loss: 0.2533349165003694
# Terminated: False | Done: True
# Episode: 81, Total Reward: -20, Epsilon: 0.44304798162617254 | Loss: 0.2512316827406708
# Terminated: True | Done: False
# Episode: 82, Total Reward: 89, Epsilon: 0.4386175018099108 | Loss: 0.07788301840432374
# Terminated: False | Done: True
# Episode: 83, Total Reward: -71, Epsilon: 0.4342313267918117 | Loss: 0.2638077886338604
# Terminated: True | Done: False
# Episode: 84, Total Reward: 66, Epsilon: 0.4298890135238936 | Loss: 0.3802877288136288
# Terminated: False | Done: True
# Episode: 85, Total Reward: 83, Epsilon: 0.42559012338865465 | Loss: 0.321261417442369
# Terminated: False | Done: True
# Episode: 86, Total Reward: 77, Epsilon: 0.4213342221547681 | Loss: 0.2239419960079249
# Terminated: False | Done: True
# Episode: 87, Total Reward: 90, Epsilon: 0.41712087993322045 | Loss: 0.2538195312372409
# Terminated: False | Done: True
# Episode: 88, Total Reward: -71, Epsilon: 0.41294967113388825 | Loss: 0.22832826862992386
# Terminated: True | Done: False
# Episode: 89, Total Reward: 40, Epsilon: 0.40882017442254937 | Loss: 0.277896227973117
# Terminated: False | Done: True
# Target model updated
# Episode: 90, Total Reward: -71, Epsilon: 0.4047319726783239 | Loss: 0.25025015695376773
# Terminated: True | Done: False
# Episode: 91, Total Reward: -20, Epsilon: 0.40068465295154065 | Loss: 0.375859741327102
# Terminated: True | Done: False
# Episode: 92, Total Reward: -20, Epsilon: 0.39667780642202527 | Loss: 0.2212321145056719
# Terminated: True | Done: False
# Episode: 93, Total Reward: 86, Epsilon: 0.392711028357805 | Loss: 0.3477334446779423
# Terminated: False | Done: True
# Episode: 94, Total Reward: 64, Epsilon: 0.38878391807422696 | Loss: 0.37267946574655453
# Terminated: False | Done: True
# Episode: 95, Total Reward: -71, Epsilon: 0.3848960788934847 | Loss: 0.2645369847648421
# Terminated: True | Done: False
# Episode: 96, Total Reward: -71, Epsilon: 0.38104711810454983 | Loss: 0.32948653870586037
# Terminated: True | Done: False
# Episode: 97, Total Reward: -71, Epsilon: 0.37723664692350434 | Loss: 0.23557455819254883
# Terminated: True | Done: False
# Episode: 98, Total Reward: -71, Epsilon: 0.37346428045426927 | Loss: 0.3145253321249776
# Terminated: True | Done: False
# Episode: 99, Total Reward: -71, Epsilon: 0.36972963764972655 | Loss: 0.2008583672532425
# Terminated: True | Done: False
# Target model updated
# Episode: 100, Total Reward: 82, Epsilon: 0.36603234127322926 | Loss: 0.07614309225264151
# Terminated: False | Done: True
# Episode: 101, Total Reward: 86, Epsilon: 0.36237201786049694 | Loss: 0.3311558896675706
# Terminated: False | Done: True
# Episode: 102, Total Reward: -20, Epsilon: 0.358748297681892 | Loss: 0.2788912454721662
# Terminated: True | Done: False
# Episode: 103, Total Reward: 67, Epsilon: 0.35516081470507305 | Loss: 0.1695941953206784
# Terminated: False | Done: True
# Episode: 104, Total Reward: -71, Epsilon: 0.3516092065580223 | Loss: 0.22617444653195903
# Terminated: True | Done: False
# Episode: 105, Total Reward: -71, Epsilon: 0.34809311449244207 | Loss: 0.1930589316264008
# Terminated: True | Done: False
# Episode: 106, Total Reward: -71, Epsilon: 0.34461218334751764 | Loss: 0.27946797080651997
# Terminated: True | Done: False
# Episode: 107, Total Reward: 48, Epsilon: 0.34116606151404244 | Loss: 0.19422508259282478
# Terminated: False | Done: True
# Episode: 108, Total Reward: -71, Epsilon: 0.337754400898902 | Loss: 0.23947424840595669
# Terminated: True | Done: False
# Episode: 109, Total Reward: -71, Epsilon: 0.334376856889913 | Loss: 0.20428886422840464
# Terminated: True | Done: False
# Target model updated
# Episode: 110, Total Reward: -71, Epsilon: 0.33103308832101386 | Loss: 0.1916330959402971
# Terminated: True | Done: False
# Episode: 111, Total Reward: -71, Epsilon: 0.3277227574378037 | Loss: 0.2518088722441257
# Terminated: True | Done: False
# Episode: 112, Total Reward: -71, Epsilon: 0.3244455298634257 | Loss: 0.1534518018327963
# Terminated: True | Done: False
# Episode: 113, Total Reward: -20, Epsilon: 0.3212010745647914 | Loss: 0.21026433662504593
# Terminated: True | Done: False
# Episode: 114, Total Reward: -71, Epsilon: 0.3179890638191435 | Loss: 0.14357531001121354
# Terminated: True | Done: False
# Episode: 115, Total Reward: -20, Epsilon: 0.31480917318095203 | Loss: 0.20444787666588446
# Terminated: True | Done: False
# Episode: 116, Total Reward: -20, Epsilon: 0.3116610814491425 | Loss: 0.2543394108138593
# Terminated: True | Done: False
# Episode: 117, Total Reward: 72, Epsilon: 0.30854447063465107 | Loss: 0.11114451208268292
# Terminated: False | Done: True
# Episode: 118, Total Reward: 53, Epsilon: 0.30545902592830454 | Loss: 0.12566816625547625
# Terminated: False | Done: True
# Episode: 119, Total Reward: -20, Epsilon: 0.3024044356690215 | Loss: 0.18780991237419048
# Terminated: True | Done: False
# Target model updated
# Episode: 120, Total Reward: -20, Epsilon: 0.29938039131233124 | Loss: 0.10973493366617104
# Terminated: True | Done: False
# Episode: 121, Total Reward: 97, Epsilon: 0.2963865873992079 | Loss: 0.5281498402357101
# Terminated: False | Done: True
# Episode: 122, Total Reward: -71, Epsilon: 0.29342272152521587 | Loss: 0.2412619833886938
# Terminated: True | Done: False
# Episode: 123, Total Reward: -71, Epsilon: 0.2904884943099637 | Loss: 0.22813749200536157
# Terminated: True | Done: False
# Episode: 124, Total Reward: -71, Epsilon: 0.28758360936686406 | Loss: 0.1618274187477498
# Terminated: True | Done: False
# Episode: 125, Total Reward: -20, Epsilon: 0.2847077732731954 | Loss: 0.1552256195823183
# Terminated: True | Done: False
# Episode: 126, Total Reward: -71, Epsilon: 0.28186069554046345 | Loss: 0.1832819873560138
# Terminated: True | Done: False
# Episode: 127, Total Reward: 64, Epsilon: 0.2790420885850588 | Loss: 0.09329862742872233
# Terminated: False | Done: True
# Episode: 128, Total Reward: -71, Epsilon: 0.2762516676992082 | Loss: 0.15492210775667278
# Terminated: True | Done: False
# Episode: 129, Total Reward: -20, Epsilon: 0.27348915102221616 | Loss: 0.18860864896911653
# Terminated: True | Done: False
# Target model updated
# Episode: 130, Total Reward: -71, Epsilon: 0.270754259511994 | Loss: 0.2760073886882208
# Terminated: True | Done: False
# Episode: 131, Total Reward: -20, Epsilon: 0.26804671691687404 | Loss: 0.31512882473671966
# Terminated: True | Done: False
# Episode: 132, Total Reward: -71, Epsilon: 0.2653662497477053 | Loss: 0.22840363954125845
# Terminated: True | Done: False
# Episode: 133, Total Reward: -71, Epsilon: 0.2627125872502282 | Loss: 0.16687352365548117
# Terminated: True | Done: False
# Episode: 134, Total Reward: -71, Epsilon: 0.2600854613777259 | Loss: 0.19459934260265355
# Terminated: True | Done: False
# Episode: 135, Total Reward: -71, Epsilon: 0.2574846067639487 | Loss: 0.1057945565375326
# Terminated: True | Done: False
# Episode: 136, Total Reward: -71, Epsilon: 0.2549097606963092 | Loss: 0.06907488067392965
# Terminated: True | Done: False
# Episode: 137, Total Reward: 96, Epsilon: 0.2523606630893461 | Loss: 0.16847505848879032
# Terminated: False | Done: True
# Episode: 138, Total Reward: -71, Epsilon: 0.24983705645845267 | Loss: 0.0855170109361046
# Terminated: True | Done: False
# Episode: 139, Total Reward: -20, Epsilon: 0.24733868589386815 | Loss: 0.09275359798325361
# Terminated: True | Done: False
# Target model updated
# Episode: 140, Total Reward: -20, Epsilon: 0.24486529903492946 | Loss: 0.08560883455785943
# Terminated: True | Done: False
# Episode: 141, Total Reward: 51, Epsilon: 0.24241664604458016 | Loss: 0.24294274788368128
# Terminated: False | Done: True
# Episode: 142, Total Reward: -71, Epsilon: 0.23999247958413436 | Loss: 0.2150119752568571
# Terminated: True | Done: False
# Episode: 143, Total Reward: -20, Epsilon: 0.23759255478829303 | Loss: 0.15676541523601079
# Terminated: True | Done: False
# Episode: 144, Total Reward: -71, Epsilon: 0.2352166292404101 | Loss: 0.0783064182585173
# Terminated: True | Done: False
# Episode: 145, Total Reward: 38, Epsilon: 0.232864462948006 | Loss: 0.17383869523180806
# Terminated: False | Done: True
# Episode: 146, Total Reward: 40, Epsilon: 0.23053581831852593 | Loss: 0.17158954582740285
# Terminated: False | Done: True
# Episode: 147, Total Reward: -20, Epsilon: 0.22823046013534068 | Loss: 0.18548242762750614
# Terminated: True | Done: False
# Episode: 148, Total Reward: -20, Epsilon: 0.22594815553398728 | Loss: 0.1566759344026599
# Terminated: True | Done: False
# Episode: 149, Total Reward: -71, Epsilon: 0.22368867397864742 | Loss: 0.135483320831538
# Terminated: True | Done: False
# Target model updated
# Episode: 150, Total Reward: -20, Epsilon: 0.22145178723886094 | Loss: 0.11401150772571526
# Terminated: True | Done: False
# Episode: 151, Total Reward: -71, Epsilon: 0.21923726936647234 | Loss: 0.2513147523757038
# Terminated: True | Done: False
# Episode: 152, Total Reward: 54, Epsilon: 0.2170448966728076 | Loss: 0.1900971124402986
# Terminated: False | Done: True
# Episode: 153, Total Reward: -20, Epsilon: 0.21487444770607952 | Loss: 0.1780392165814909
# Terminated: True | Done: False
# Episode: 154, Total Reward: -20, Epsilon: 0.21272570322901874 | Loss: 0.11420622014825504
# Terminated: True | Done: False
# Episode: 155, Total Reward: -71, Epsilon: 0.21059844619672854 | Loss: 0.12827937322182267
# Terminated: True | Done: False
# Episode: 156, Total Reward: -20, Epsilon: 0.20849246173476127 | Loss: 0.10690479754762044
# Terminated: True | Done: False
# Episode: 157, Total Reward: -20, Epsilon: 0.20640753711741366 | Loss: 0.10688852336045489
# Terminated: True | Done: False
# Episode: 158, Total Reward: -20, Epsilon: 0.20434346174623952 | Loss: 0.10696195512179694
# Terminated: True | Done: False
# Episode: 159, Total Reward: -20, Epsilon: 0.20230002712877712 | Loss: 0.06422659110583635
# Terminated: True | Done: False
# Target model updated
# Episode: 160, Total Reward: -20, Epsilon: 0.20027702685748935 | Loss: 0.035615463653392666
# Terminated: True | Done: False
# Episode: 161, Total Reward: -71, Epsilon: 0.19827425658891445 | Loss: 0.11756542043655481
# Terminated: True | Done: False
# Episode: 162, Total Reward: -71, Epsilon: 0.1962915140230253 | Loss: 0.04293768341137724
# Terminated: True | Done: False
# Episode: 163, Total Reward: -20, Epsilon: 0.19432859888279505 | Loss: 0.04277106356583215
# Terminated: True | Done: False
# Episode: 164, Total Reward: -71, Epsilon: 0.1923853128939671 | Loss: 0.05699004487043029
# Terminated: True | Done: False
# Episode: 165, Total Reward: -71, Epsilon: 0.19046145976502743 | Loss: 0.05698083889162365
# Terminated: True | Done: False
# Episode: 166, Total Reward: -20, Epsilon: 0.18855684516737714 | Loss: 0.08547628324784864
# Terminated: True | Done: False
# Episode: 167, Total Reward: -71, Epsilon: 0.18667127671570335 | Loss: 0.08553942125942265
# Terminated: True | Done: False
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\marks\Documents\Uni\multi-agent-systems\int_dqn_test.ipynb Cell 7 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/marks/Documents/Uni/multi-agent-systems/int_dqn_test.ipynb#X13sZmlsZQ%3D%3D?line=27'>28</a> minibatch_indices = np.random.choice(len(agent.memory), agent.batch_size, replace=False)
#      <a href='vscode-notebook-cell:/c%3A/Users/marks/Documents/Uni/multi-agent-systems/int_dqn_test.ipynb#X13sZmlsZQ%3D%3D?line=28'>29</a> minibatch = [agent.memory[i] for i in minibatch_indices]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/marks/Documents/Uni/multi-agent-systems/int_dqn_test.ipynb#X13sZmlsZQ%3D%3D?line=29'>30</a> states_batch, actions_batch, targets_batch = agent.process_minibatch(minibatch)
#      <a href='vscode-notebook-cell:/c%3A/Users/marks/Documents/Uni/multi-agent-systems/int_dqn_test.ipynb#X13sZmlsZQ%3D%3D?line=30'>31</a> loss = agent.train_one_step(states_batch, actions_batch, targets_batch)
#      <a href='vscode-notebook-cell:/c%3A/Users/marks/Documents/Uni/multi-agent-systems/int_dqn_test.ipynb#X13sZmlsZQ%3D%3D?line=31'>32</a> episode_losses.append(loss)
#
# c:\Users\marks\Documents\Uni\multi-agent-systems\int_dqn_test.ipynb Cell 7 line 7
#      <a href='vscode-notebook-cell:/c%3A/Users/marks/Documents/Uni/multi-agent-systems/int_dqn_test.ipynb#X13sZmlsZQ%3D%3D?line=71'>72</a>     q_values[action] = reward
#      <a href='vscode-notebook-cell:/c%3A/Users/marks/Documents/Uni/multi-agent-systems/int_dqn_test.ipynb#X13sZmlsZQ%3D%3D?line=72'>73</a> else:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/marks/Documents/Uni/multi-agent-systems/int_dqn_test.ipynb#X13sZmlsZQ%3D%3D?line=73'>74</a>     q_values[action] = reward + self.gamma * self.get_maxQ(next_state)
#      <a href='vscode-notebook-cell:/c%3A/Users/marks/Documents/Uni/multi-agent-systems/int_dqn_test.ipynb#X13sZmlsZQ%3D%3D?line=74'>75</a> states.append(state)
#      <a href='vscode-notebook-cell:/c%3A/Users/marks/Documents/Uni/multi-agent-systems/int_dqn_test.ipynb#X13sZmlsZQ%3D%3D?line=75'>76</a> actions.append(action)
#
# c:\Users\marks\Documents\Uni\multi-agent-systems\int_dqn_test.ipynb Cell 7 line 5
#      <a href='vscode-notebook-cell:/c%3A/Users/marks/Documents/Uni/multi-agent-systems/int_dqn_test.ipynb#X13sZmlsZQ%3D%3D?line=55'>56</a> def get_maxQ(self, s):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/marks/Documents/Uni/multi-agent-systems/int_dqn_test.ipynb#X13sZmlsZQ%3D%3D?line=56'>57</a>     return torch.max(self.model2(torch.from_numpy(s).float())).float()
#
# File e:\miniconda\envs\ultrasound\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File e:\miniconda\envs\ultrasound\lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File e:\miniconda\envs\ultrasound\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File e:\miniconda\envs\ultrasound\lib\site-packages\torch\nn\modules\activation.py:103, in ReLU.forward(self, input)
#     102 def forward(self, input: Tensor) -> Tensor:
# --> 103     return F.relu(input, inplace=self.inplace)
#
# File e:\miniconda\envs\ultrasound\lib\site-packages\torch\nn\functional.py:1457, in relu(input, inplace)
#    1455     result = torch.relu_(input)
#    1456 else:
# -> 1457     result = torch.relu(input)
#    1458 return result
#
# KeyboardInterrupt:
